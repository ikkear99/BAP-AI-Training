# %%
# import libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
print(os.listdir('.\data'))
# Out:
# ['2015.csv', '2016.csv', '2017.csv', '2018.csv', '2019.csv']

# %%
# load datasets from csv files
x = 2015
df_ls = []
while True:
    df = pd.read_csv(f'./data/{x}.csv')
    df_ls.append(df)
    x += 1
    if x == 2020:
        break
len(df_ls)

# %%
for i in range(len(df_ls)):
    print('Dataset of the year 201{} :'.format(i+5))
    display(df_ls[i].head(5))
# Out:
# Dataset of the year 2015 :
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
# size of datasets
for i in range(len(df_ls)):
    print("size of dataset 201{}: {}".format(i+5, df_ls[i].shape))
# Out:
# size of dataset 2015: (158, 12)
# size of dataset 2016: (157, 13)
# size of dataset 2017: (155, 12)
# size of dataset 2018: (156, 9)
# size of dataset 2019: (156, 9)

# %%
# show to veiw name columns in dataset
for i in range(len(df_ls)):
    print('columb name of 201{} dataset: {}'.format(i+5, df_ls[i].columns))
# Out:
# columb name of 2015 dataset: Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')
# columb name of 2016 dataset: Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')
# columb name of 2017 dataset: Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')
# ...

# %%
# rename clumns dataset 2015 to clumns standard
df_ls[0].rename(columns={'Economy (GDP per Capita)' : 'GDP',
                        'Health (Life Expectancy)' : 'Life',
                        'Trust (Government Corruption)' : 'Trust'}, inplace = True)
df_ls[0].head(5)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error      GDP   Family     Life  Freedom    Trust  Generosity  \
# 0         0.03411  1.39651  1.34951  0.94143  0.66557  0.41978     0.29678
# 1         0.04884  1.30232  1.40223  0.94784  0.62877  0.14145     0.43630
# 2         0.03328  1.32548  1.36058  0.87464  0.64938  0.48357     0.34139
# 3         0.03880  1.45900  1.33095  0.88521  0.66973  0.36503     0.34699
# 4         0.03553  1.32629  1.32261  0.90563  0.63297  0.32957     0.45811
#
#    Dystopia Residual
# 0            2.51738
# 1            2.70201
# 2            2.49204
# 3            2.46531
# ...

# %%
# rename clumns dataset 2016 to clumns standard
df_ls[1].rename(columns={'Economy (GDP per Capita)' : 'GDP',
                        'Health (Life Expectancy)' : 'Life',
                        'Trust (Government Corruption)' : 'Trust'}, inplace = True)
df_ls[1].head(5)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval      GDP   Family  \
# 0                      7.460                      7.592  1.44178  1.16374
# 1                      7.428                      7.590  1.52733  1.14524
# 2                      7.333                      7.669  1.42666  1.18326
# 3                      7.421                      7.575  1.57744  1.12690
# 4                      7.351                      7.475  1.40598  1.13464
#
#       Life  Freedom    Trust  Generosity  Dystopia Residual
# 0  0.79504  0.57941  0.44453     0.36171            2.73939
# ...

# %%
# rename clumns dataset 2017 to clumns standard
df_ls[2].rename(columns = {'Happiness.Rank' : 'Happiness Rank',
                        'Happiness.Score' : 'Happiness Score',
                        'Economy..GDP.per.Capita.' : 'GDP',
                        'Health..Life.Expectancy.' : 'Life',
                        'Dystopia.Residual' : 'Dystopia Residual',
                        'Trust..Government.Corruption.' : 'Trust'}, inplace = True)
df_ls[2].head(5)
# Out:
#        Country  Happiness Rank  Happiness Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#         GDP    Family      Life   Freedom  Generosity     Trust  \
# 0  1.616463  1.533524  0.796667  0.635423    0.362012  0.315964
# 1  1.482383  1.551122  0.792566  0.626007    0.355280  0.400770
# 2  1.480633  1.610574  0.833552  0.627163    0.475540  0.153527
# 3  1.564980  1.516912  0.858131  0.620071    0.290549  0.367007
# 4  1.443572  1.540247  0.809158  0.617951    0.245483  0.382612
#
#    Dystopia Residual
# 0           2.277027
# 1           2.313707
# 2           2.322715
# 3           2.276716
# ...

# %%
# rename clumns dataset 2018 to clumns standard
df_ls[3].rename(columns = {'Overall rank' : 'Happiness Rank',
                        'Score' : 'Happiness Score',
                        'Country or region' : 'Country',
                        'Social support' : 'Family',
                        'Freedom to make life choices' : 'Freedom',
                        'GDP per capita' : 'GDP',
                        'Healthy life expectancy' : 'Life',
                        'Perceptions of corruption' : 'Trust'}, inplace = True)
df_ls[3].head()
# Out:
#    Happiness Rank      Country  Happiness Score    GDP  Family   Life  \
# 0               1      Finland            7.632  1.305   1.592  0.874
# 1               2       Norway            7.594  1.456   1.582  0.861
# 2               3      Denmark            7.555  1.351   1.590  0.868
# 3               4      Iceland            7.495  1.343   1.644  0.914
# 4               5  Switzerland            7.487  1.420   1.549  0.927
#
#    Freedom  Generosity  Trust
# 0    0.681       0.202  0.393
# 1    0.686       0.286  0.340
# 2    0.683       0.284  0.408
# 3    0.677       0.353  0.138
# 4    0.660       0.256  0.357

# %%
# rename clumns dataset 2019 to clumns standard
df_ls[4].rename(columns = {'Overall rank' : 'Happiness Rank',
                        'Score' : 'Happiness Score',
                        'Country or region' : 'Country',
                        'Social support' : 'Family',
                        'Freedom to make life choices' : 'Freedom',
                        'GDP per capita' : 'GDP',
                        'Healthy life expectancy' : 'Life',
                        'Perceptions of corruption' : 'Trust'}, inplace = True)
df_ls[4].head()
# Out:
#    Happiness Rank      Country  Happiness Score    GDP  Family   Life  \
# 0               1      Finland            7.769  1.340   1.587  0.986
# 1               2      Denmark            7.600  1.383   1.573  0.996
# 2               3       Norway            7.554  1.488   1.582  1.028
# 3               4      Iceland            7.494  1.380   1.624  1.026
# 4               5  Netherlands            7.488  1.396   1.522  0.999
#
#    Freedom  Generosity  Trust
# 0    0.596       0.153  0.393
# 1    0.592       0.252  0.410
# 2    0.603       0.271  0.341
# 3    0.591       0.354  0.118
# 4    0.557       0.322  0.298

# %%
# add year column for each dataset
for i, df in enumerate(df_ls, 2015):
    df['Year'] = i

# %%
df_ls[0].head(5)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error      GDP   Family     Life  Freedom    Trust  Generosity  \
# 0         0.03411  1.39651  1.34951  0.94143  0.66557  0.41978     0.29678
# 1         0.04884  1.30232  1.40223  0.94784  0.62877  0.14145     0.43630
# 2         0.03328  1.32548  1.36058  0.87464  0.64938  0.48357     0.34139
# 3         0.03880  1.45900  1.33095  0.88521  0.66973  0.36503     0.34699
# 4         0.03553  1.32629  1.32261  0.90563  0.63297  0.32957     0.45811
#
#    Dystopia Residual  Year
# 0            2.51738  2015
# 1            2.70201  2015
# 2            2.49204  2015
# ...

# %%
# calculate "Standard Error" column for both 2016
df_ls[1]['Standard Error'] = round((df_ls[1]['Upper Confidence Interval'] - df_ls[1]['Lower Confidence Interval'])/2,3)
df_ls[1]['Standard Error'].head(5)
# Out:
# 0    0.066
# 1    0.081
# 2    0.168
# 3    0.077
# 4    0.062
# Name: Standard Error, dtype: float64

# %%
# calculate "Standard Error" column for both 2016-2017
df_ls[2]['Standard Error'] = round((df_ls[2]['Whisker.high'] - df_ls[2]['Whisker.low'])/2,3)
df_ls[1]['Standard Error'].head(5)
# Out:
# 0    0.066
# 1    0.081
# 2    0.168
# 3    0.077
# 4    0.062
# Name: Standard Error, dtype: float64

# %%
temp = pd.merge(df_ls[0][['Country', 'Standard Error']], df_ls[1][['Country', 'Standard Error']], on = 'Country')
temp.head(5)
# Out:
#        Country  Standard Error_x  Standard Error_y
# 0  Switzerland           0.03411             0.081
# 1      Iceland           0.04884             0.168
# 2      Denmark           0.03328             0.066
# 3       Norway           0.03880             0.077
# 4       Canada           0.03553             0.069

# %%
temp.rename(columns= {'Standard Error_x': 'Standard Error 2015', 'Standard Error_y': 'Standard Error 2016'}, inplace= True)
temp.head(5)
# Out:
#        Country  Standard Error 2015  Standard Error 2016
# 0  Switzerland              0.03411                0.081
# 1      Iceland              0.04884                0.168
# 2      Denmark              0.03328                0.066
# 3       Norway              0.03880                0.077
# 4       Canada              0.03553                0.069

# %%
# add Standard Error 2017 to Standard Error dataframe
temp = pd.merge(temp, df_ls[2][['Country', 'Standard Error']], on='Country')
temp.rename(columns= {'Standard Error': 'Standard Error 2016', })
temp.rename(columns={'Standard Error': 'Standard Error 2017'}, inplace=True)
temp.head(5)
# Out:
#        Country  Standard Error 2015  Standard Error 2016  Standard Error 2017
# 0  Switzerland              0.03411                0.081                0.068
# 1      Iceland              0.04884                0.168                0.118
# 2      Denmark              0.03328                0.066                0.060
# 3       Norway              0.03880                0.077                0.057
# 4       Canada              0.03553                0.069                0.068

# %%
# claculate Standard Error values for df2018
temp['Standard Error 2018'] =  round(temp.mean(axis=1), 4)
temp['Standard Error 2019'] =  round(temp.mean(axis=1), 3)
temp.head(5)
# Out:
#        Country  Standard Error 2015  Standard Error 2016  Standard Error 2017  \
# 0  Switzerland              0.03411                0.081                0.068
# 1      Iceland              0.04884                0.168                0.118
# 2      Denmark              0.03328                0.066                0.060
# 3       Norway              0.03880                0.077                0.057
# 4       Canada              0.03553                0.069                0.068
#
#    Standard Error 2018  Standard Error 2019
# 0               0.0610                0.061
# 1               0.1116                0.112
# 2               0.0531                0.053
# 3               0.0576                0.058
# 4               0.0575                0.058

# %%
df_ls[3] = pd.merge(df_ls[3], temp[['Country', 'Standard Error 2018']], on='Country')
df_ls[3].rename(columns={'Standard Error 2018': 'Standard Error'}, inplace=True)
df_ls[4] = pd.merge(df_ls[4], temp[['Country', 'Standard Error 2019']], on='Country')
df_ls[4].rename(columns={'Standard Error 2019': 'Standard Error'}, inplace=True)

# %%
df_ls[3].head()
# Out:
#    Happiness Rank      Country  Happiness Score    GDP  Family   Life  \
# 0               1      Finland            7.632  1.305   1.592  0.874
# 1               2       Norway            7.594  1.456   1.582  0.861
# 2               3      Denmark            7.555  1.351   1.590  0.868
# 3               4      Iceland            7.495  1.343   1.644  0.914
# 4               5  Switzerland            7.487  1.420   1.549  0.927
#
#    Freedom  Generosity  Trust  Year  Standard Error
# 0    0.681       0.202  0.393  2018          0.0508
# 1    0.686       0.286  0.340  2018          0.0576
# 2    0.683       0.284  0.408  2018          0.0531
# 3    0.677       0.353  0.138  2018          0.1116
# 4    0.660       0.256  0.357  2018          0.0610

# %%
df_ls[4].head()
# Out:
#    Happiness Rank      Country  Happiness Score    GDP  Family   Life  \
# 0               1      Finland            7.769  1.340   1.587  0.986
# 1               2      Denmark            7.600  1.383   1.573  0.996
# 2               3       Norway            7.554  1.488   1.582  1.028
# 3               4      Iceland            7.494  1.380   1.624  1.026
# 4               5  Netherlands            7.488  1.396   1.522  0.999
#
#    Freedom  Generosity  Trust  Year  Standard Error
# 0    0.596       0.153  0.393  2019           0.051
# 1    0.592       0.252  0.410  2019           0.053
# 2    0.603       0.271  0.341  2019           0.058
# 3    0.591       0.354  0.118  2019           0.112
# 4    0.557       0.322  0.298  2019           0.044

# %%
# # drop columns 
for i, df in enumerate(df_ls, 2015):
    # drop "Dystopia Residual" columns
    if 'Dystopia Residual' in df:
        df.drop(['Dystopia Residual'], inplace = True, axis = 1)
    # drop "Confidence Interval" columns
    if ('Lower Confidence Interval' and 'Upper Confidence Interval') in df:
        df.drop(['Lower Confidence Interval', 'Upper Confidence Interval'], inplace = True, axis = 1)
    # drop "Whisker" columns
    if ('Whisker.high' and 'Whisker.low') in df:
        df.drop(['Whisker.high', 'Whisker.low'], inplace = True, axis = 1)

# %%
# check Non value
for i, df in enumerate(df_ls, 2015):
    print('miss data of 201{}: {}'.format(i, df.isnull().sum()))
# Out:
# miss data of 2012015: Country            0
# Region             0
# Happiness Rank     0
# Happiness Score    0
# Standard Error     0
# GDP                0
# Family             0
# Life               0
# Freedom            0
# Trust              0
# Generosity         0
# Year               0
# dtype: int64
# miss data of 2012016: Country            0
# Region             0
# Happiness Rank     0
# Happiness Score    0
# GDP                0
# Family             0
# Life               0
# Freedom            0
# Trust              0
# Generosity         0
# Year               0
# Standard Error     0
# dtype: int64
# miss data of 2012017: Country            0
# Happiness Rank     0
# Happiness Score    0
# GDP                0
# Family             0
# Life               0
# Freedom            0
# Generosity         0
# Trust              0
# Year               0
# Standard Error     0
# dtype: int64
# miss data of 2012018: Happiness Rank     0
# Country            0
# ...

# %%
# show Null
df_ls[3][df_ls[3].isnull().any(axis=1)]
# Out:
#     Happiness Rank               Country  Happiness Score    GDP  Family  \
# 19              20  United Arab Emirates            6.774  2.096   0.776
#
#     Life  Freedom  Generosity  Trust  Year  Standard Error
# 19  0.67    0.284       0.186    NaN  2018          0.0634

# %%
# eliminate nun by averaging the values ​​in previous years
previous_trust_uae = [df_ls[0][df_ls[0]['Country'] == 'United Arab Emirates']['Trust'].item(), df_ls[1][df_ls[1]['Country'] == 'United Arab Emirates']['Trust'].item(), df_ls[2][df_ls[2]['Country'] == 'United Arab Emirates']['Trust'].item()]
df_ls[3].loc[19, ['Trust']] = sum(previous_trust_uae) / len(previous_trust_uae)

# %%
giant_df = pd.concat(df_ls)
eda_df = giant_df

# %%
eda_df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error         GDP  \
# count      755.000000       755.000000      755.000000  755.000000
# mean        77.883444         5.401142        0.080205    0.923644
# std         45.093621         1.124188        0.034696    0.402192
# min          1.000000         2.693000        0.018480    0.000000
# 25%         39.000000         4.515500        0.059000    0.625345
# 50%         78.000000         5.339000        0.076000    0.986000
# 75%        117.000000         6.220500        0.093000    1.239710
# max        158.000000         7.769000        0.270000    2.096000
#
#            Family        Life     Freedom       Trust  Generosity         Year
# count  755.000000  755.000000  755.000000  755.000000  755.000000   755.000000
# mean     1.080364    0.617085    0.410866    0.125738    0.219489  2016.937748
# std      0.327114    0.243383    0.152732    0.106879    0.123848     1.407669
# ...

# %%
eda_df.corr()
# Out:
#                  Happiness Rank  Happiness Score  Standard Error       GDP  \
# Happiness Rank         1.000000        -0.992367        0.183914 -0.793974
# Happiness Score       -0.992367         1.000000       -0.207391  0.788540
# Standard Error         0.183914        -0.207391        1.000000 -0.121017
# GDP                   -0.793974         0.788540       -0.121017  1.000000
# Family                -0.643458         0.645452       -0.186921  0.574280
# Life                  -0.742858         0.741656       -0.320728  0.779290
# Freedom               -0.542734         0.554211       -0.184576  0.348256
# Trust                 -0.385330         0.409883       -0.188123  0.325162
# Generosity            -0.116040         0.136621       -0.024127 -0.014971
# Year                  -0.030389         0.031158        0.160687  0.043110
#
#                    Family      Life   Freedom     Trust  Generosity      Year
# ...

# %%
# Data Visualisation
import seaborn as sns
f, ax = plt.subplots(figsize = (13,10))
sns.heatmap(eda_df.corr(), annot=True, center=1, ax=ax, fmt = ".2f")
# Out:
# <AxesSubplot:>

# %%
# Comment:  The things that influence more than 50% to make people in a country feel happy at the top is the average income GDP accounted for 0.78, the second dominant factor was: "Life Expectancy" accounted for 0.74, ranked 3rd. is: 'Family Support' with 0.65, 4th is "Freedom" with 0.55

# %%
import plotly.express as px

# %%
# The Top 10 Happiest Countries in The World <br> (Bubble Size Indicates GDP)
import plotly.express as px
happiest_countries = eda_df.groupby(['Country'], sort = False)['Happiness Score', 'Year', 'GDP'].max()
top10 = happiest_countries.sort_values('Happiness Score', ascending = False)[:15]
fig = px.scatter(top10,
                x = top10.index,
                y = 'Happiness Score',
                size = 'GDP',
                color = top10.index,
                template = 'xgridoff',
                animation_frame = 'Year',
                title = 'The Top 10 Happiest Countries in The World <br> (Bubble Size Indicates GDP)')
fig.show()
# Out:
# C:\Users\ADMIN\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:2: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
# Does Money Bus Happiness?
fig = px.scatter(eda_df,
                x='GDP',
                y='Happiness Score',
                size='Trust',
                color='Country',
                template='xgridoff',
                animation_frame='Year',
                labels={'Life':'Life Expectancy'},
                title='GDP vs Happiness Score from 2015-2017 <br> (Bubble Size Indicates Trust)')
fig.show()

# %%
# 
fig = px.scatter(eda_df,
                x='Life',
                y='Happiness Score',
                size='GDP',
                color='Country',
                template='xgridoff',
                animation_frame='Year',
                labels={'Life':'Life Expectancy'},
                title='Life Expectancy vs Happiness Score for Each Country from 2015-2017 <br> (Bubble Size Indicates GDP)')
fig.show()

# %%
 # Family Support vs Happiness Score for Each Country from 2015-2017
 fig = px.scatter(eda_df,
                x='Family',
                y='Happiness Score',
                size='GDP',
                color='Country',
                template='xgridoff',
                animation_frame='Year',
                labels={'Family':'Family Expectancy'},
                title='Family Support vs Happiness Score for Each Country from 2015-2017<br> (Bubble Size Indicates GDP)')
fig.show()

# %%
# Relation of Freedom to Happiness Score?
fig = px.scatter(eda_df,
                x='Freedom',
                y='Happiness Score',
                size='GDP',
                color='Country',
                template='xgridoff',
                animation_frame='Year',
                labels={'Life':'Life Expectancy'},
                title='Freedom vs Happiness Score for Each Country from 2015-2017 <br> (Bubble Size Indicates GDP)')
fig.show()
